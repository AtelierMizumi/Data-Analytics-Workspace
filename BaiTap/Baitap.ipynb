# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#import libraries:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
#read dataset
df_2020 = pd.read_csv("/content/drive/My Drive/BaiTapNhom/diem_thi_thpt_2022.csv")
df_2021 = pd.read_csv("/content/drive/My Drive/BaiTapNhom/diem_thi_thpt_2022.csv")
df_2023 = pd.read_csv("/content/drive/My Drive/BaiTapNhom/diem_thi_thpt_2023.csv")
df_2022 = pd.read_csv("/content/drive/My Drive/BaiTapNhom/diem_thi_thpt_2022.csv")
df_2024 = pd.read_csv("/content/drive/My Drive/BaiTapNhom/diem_thi_thpt_2024.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-ecb31aef45e3> in <cell line: 0>()
#       1 #read dataset
# ----> 2 df_2020 = pd.read_csv("/content/drive/My Drive/BaiTapNhom/diem_thi_thpt_2022.csv")
#       3 df_2021 = pd.read_csv("/content/drive/My Drive/BaiTapNhom/diem_thi_thpt_2022.csv")
#       4 df_2023 = pd.read_csv("/content/drive/My Drive/BaiTapNhom/diem_thi_thpt_2023.csv")
#       5 df_2022 = pd.read_csv("/content/drive/My Drive/BaiTapNhom/diem_thi_thpt_2022.csv")
#
# ...

# %%
df_2020.head()

# %%
df_2021.head()

# %%
df_2022.head()

# %%
df_2023.head()

# %%
df_2024.head()

# %%
rows_2020, columns_2020 = df_2020.shape

# %%
rows_2021, columns_2021 = df_2021.shape

# %%
rows_2022, columns_2022 = df_2022.shape

# %%
rows_2023, columns_2023 = df_2023.shape

# %%
rows_2024, columns_2024 = df_2024.shape
